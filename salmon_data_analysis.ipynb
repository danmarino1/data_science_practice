# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
salmon_data = pd.read_pickle('salmon_data.pkl').sample(6000)
salmon_data.to_pickle('salmon_data.pkl')
salmon_data.head()
# Out:
#           Species      Length.Measurement.Type  sampleYear    ASLProjectType
# 7776219   sockeye      mid-eye to fork of tail      2003.0  commercial catch  \
# 8159307   sockeye      mid-eye to fork of tail      1986.0  commercial catch
# 8503621   sockeye      mid-eye to fork of tail      1976.0  commercial catch
# 217179    chinook      mid-eye to fork of tail      1988.0  commercial catch
# 13006531  sockeye  post orbit to hypural plate      1987.0  commercial catch
#
#                  LocationID  sampleDate  Length  Weight
# 7776219         Kuthai Lake  2003-07-28   555.0     NaN  \
# 8159307        Nelson River  1986-06-22   440.0     NaN
# 8503621   Nushagak District  1976-07-07   539.0     NaN
# 217179         District 110  1988-06-07   658.0     NaN
# 13006531       Tahltan Lake  1987-08-01   573.0     NaN
#
#                                     Sex  Salt.Water.Age  ... Flag     Gear
# 7776219                          female             3.0  ...  NaN     weir  \
# ...

# %%
salmon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6000 entries, 7776219 to 5908279
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Species                   6000 non-null   object
#  1   Length.Measurement.Type   5389 non-null   object
#  2   sampleYear                5997 non-null   float64
#  3   ASLProjectType            5907 non-null   object
#  4   LocationID                6000 non-null   object
#  5   sampleDate                5997 non-null   object
#  6   Length                    4469 non-null   float64
#  7   Weight                    321 non-null    float64
#  8   Sex                       5402 non-null   object
#  9   Salt.Water.Age            4944 non-null   float64
#  10  DataSource                6000 non-null   object
#  11  cardNo                    2588 non-null   object
#  12  fishNum                   2678 non-null   object
# ...
